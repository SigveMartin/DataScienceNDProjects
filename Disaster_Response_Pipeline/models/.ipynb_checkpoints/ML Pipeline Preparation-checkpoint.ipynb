# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import nltk
nltk.download(['punkt', 'wordnet'])

import pandas as pd 
import numpy as np
from sqlalchemy import create_engine
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

from sklearn.externals import joblib
# Out:
# [nltk_data] Downloading package punkt to /Users/Sigve/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/Sigve/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /miniconda2/envs/dataSci/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
# load data from database
engine = create_engine('sqlite:///../data/DisasterResponse.db')
df = pd.read_sql_table('coded_responses', engine)  
X = df["message"]
Y = df.drop(columns=["message","id","genre","original"])

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
        ('vect', CountVectorizer(tokenizer=tokenize)),
        ('tfidf', TfidfTransformer()),
        ('clf', MultiOutputClassifier(RandomForestClassifier(n_estimators=100, random_state=1)))
    ])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y)
# train classifier
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('vect',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=<function tokenize at...
#                                                                         ccp_alpha=0.0,
#                                                                         class_weight=None,
#                                                                         criterion='gini',
#                                                                         max_depth=None,
#                                                                         max_features='auto',
#                                                                         max_leaf_nodes=None,
#                                                                         max_samples=None,
#                                                                         min_impurity_decrease=0.0,
#                                                                         min_impurity_split=None,
#                                                                         min_samples_leaf=1,
#                                                                         min_samples_split=2,
#                                                                         min_weight_fraction_leaf=0.0,
#                                                                         n_estimators=100,
#                                                                         n_jobs=None,
#                                                                         oob_score=False,
#                                                                         random_state=1,
#                                                                         verbose=0,
#                                                                         warm_start=False),
#                                        n_jobs=None))],
#          verbose=False)

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
def performance_report(model,x_test,y_test):
    y_pred = model.predict(x_test)
    y_pred=pd.DataFrame(data=y_pred,columns=list(y_test.columns))
    for column in y_test:
        print("Column: {}:\n\n".format(column),classification_report(y_test[column].values, y_pred[column].values))

# %%
performance_report(pipeline,X_test,y_test)
# Out:
# Column: related:
#
#                precision    recall  f1-score   support
#
#            0       0.31      0.02      0.03      1539
#            1       0.76      0.99      0.86      4967
#            2       0.40      0.04      0.08        46
#
#     accuracy                           0.75      6552
#    macro avg       0.49      0.35      0.32      6552
# weighted avg       0.65      0.75      0.66      6552
#
# Column: request:
#
#                precision    recall  f1-score   support
#
#            0       0.83      0.99      0.90      5424
#            1       0.41      0.02      0.04      1128
#
#     accuracy                           0.83      6552
#    macro avg       0.62      0.51      0.47      6552
# weighted avg       0.76      0.83      0.76      6552
#
# Column: offer:
#
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      6516
#            1       0.00      0.00      0.00        36
#
#     accuracy                           0.99      6552
#    macro avg       0.50      0.50      0.50      6552
# weighted avg       0.99      0.99      0.99      6552
#
# Column: aid_related:
#
#                precision    recall  f1-score   support
#
#            0       0.59      0.90      0.71      3817
#            1       0.47      0.13      0.20      2735
#
#     accuracy                           0.58      6552
#    macro avg       0.53      0.51      0.46      6552
# weighted avg       0.54      0.58      0.50      6552
#
# Column: medical_help:
#
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      6018
#            1       0.00      0.00      0.00       534
#
#     accuracy                           0.92      6552
#    macro avg       0.46      0.50      0.48      6552
# weighted avg       0.84      0.92      0.88      6552
#
# Column: medical_products:
#
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6213
#            1       0.00      0.00      0.00       339
#
#     accuracy                           0.95      6552
#    macro avg       0.47      0.50      0.49      6552
# weighted avg       0.90      0.95      0.92      6552
#
# Column: search_and_rescue:
#
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      6384
#            1       0.00      0.00      0.00       168
#
#     accuracy                           0.97      6552
#    macro avg       0.49      0.50      0.49      6552
# weighted avg       0.95      0.97      0.96      6552
#
# Column: security:
#
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6438
#            1       0.00      0.00      0.00       114
#
#     accuracy                           0.98      6552
#    macro avg       0.49      0.50      0.50      6552
# weighted avg       0.97      0.98      0.97      6552
#
# Column: military:
#
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6349
#            1       0.00      0.00      0.00       203
#
#     accuracy                           0.97      6552
#    macro avg       0.48      0.50      0.49      6552
# weighted avg       0.94      0.97      0.95      6552
#
# Column: child_alone:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6552
#
#     accuracy                           1.00      6552
#    macro avg       1.00      1.00      1.00      6552
# weighted avg       1.00      1.00      1.00      6552
#
# Column: water:
#
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      6126
#            1       0.12      0.00      0.01       426
#
#     accuracy                           0.93      6552
#    macro avg       0.53      0.50      0.49      6552
# weighted avg       0.88      0.93      0.90      6552
#
# Column: food:
#
#                precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      5844
#            1       0.28      0.01      0.01       708
#
#     accuracy                           0.89      6552
#    macro avg       0.59      0.50      0.48      6552
# weighted avg       0.83      0.89      0.84      6552
#
# Column: shelter:
#
#                precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95      5980
#            1       0.08      0.00      0.00       572
#
#     accuracy                           0.91      6552
#    macro avg       0.49      0.50      0.48      6552
# weighted avg       0.84      0.91      0.87      6552
#
# Column: clothing:
#
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6453
#            1       0.00      0.00      0.00        99
#
#     accuracy                           0.98      6552
#    macro avg       0.49      0.50      0.50      6552
# weighted avg       0.97      0.98      0.98      6552
#
# Column: money:
#
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6391
#            1       0.00      0.00      0.00       161
#
#     accuracy                           0.98      6552
#    macro avg       0.49      0.50      0.49      6552
# weighted avg       0.95      0.98      0.96      6552
#
# Column: missing_people:
#
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6478
#            1       0.00      0.00      0.00        74
#
#     accuracy                           0.99      6552
#    macro avg       0.49      0.50      0.50      6552
# weighted avg       0.98      0.99      0.98      6552
#
# Column: refugees:
#
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      6336
#            1       0.00      0.00      0.00       216
#
#     accuracy                           0.97      6552
#    macro avg       0.48      0.50      0.49      6552
# weighted avg       0.94      0.97      0.95      6552
#
# Column: death:
#
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6265
#            1       0.00      0.00      0.00       287
#
#     accuracy                           0.96      6552
#    macro avg       0.48      0.50      0.49      6552
# weighted avg       0.91      0.96      0.93      6552
# /home/smp/anaconda3/envs/myenv/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Column: other_aid:
#
#                precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93      5682
#            1       0.08      0.00      0.01       870
#
#     accuracy                           0.86      6552
#    macro avg       0.47      0.50      0.47      6552
# weighted avg       0.76      0.86      0.80      6552
#
# Column: infrastructure_related:
#
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97      6116
#            1       0.33      0.00      0.00       436
#
#     accuracy                           0.93      6552
#    macro avg       0.63      0.50      0.49      6552
# weighted avg       0.89      0.93      0.90      6552
#
# Column: transport:
#
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6272
#            1       0.00      0.00      0.00       280
#
#     accuracy                           0.96      6552
#    macro avg       0.48      0.50      0.49      6552
# weighted avg       0.92      0.96      0.94      6552
#
# Column: buildings:
#
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6218
#            1       0.09      0.00      0.01       334
#
#     accuracy                           0.95      6552
#    macro avg       0.52      0.50      0.49      6552
# weighted avg       0.91      0.95      0.92      6552
#
# Column: electricity:
#
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6419
#            1       0.00      0.00      0.00       133
#
#     accuracy                           0.98      6552
#    macro avg       0.49      0.50      0.49      6552
# weighted avg       0.96      0.98      0.97      6552
#
# Column: tools:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6526
#            1       0.00      0.00      0.00        26
#
#     accuracy                           1.00      6552
#    macro avg       0.50      0.50      0.50      6552
# weighted avg       0.99      1.00      0.99      6552
#
# Column: hospitals:
#
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6467
#            1       0.00      0.00      0.00        85
#
#     accuracy                           0.99      6552
#    macro avg       0.49      0.50      0.50      6552
# weighted avg       0.97      0.99      0.98      6552
#
# Column: shops:
#
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6526
#            1       0.00      0.00      0.00        26
#
#     accuracy                           1.00      6552
#    macro avg       0.50      0.50      0.50      6552
# weighted avg       0.99      1.00      0.99      6552
#
# Column: aid_centers:
#
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6469
#            1       0.00      0.00      0.00        83
#
#     accuracy                           0.99      6552
#    macro avg       0.49      0.50      0.50      6552
# weighted avg       0.97      0.99      0.98      6552
#
# Column: other_infrastructure:
#
#                precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      6267
#            1       0.00      0.00      0.00       285
#
#     accuracy                           0.96      6552
#    macro avg       0.48      0.50      0.49      6552
# weighted avg       0.91      0.96      0.94      6552
#
# Column: weather_related:
#
#                precision    recall  f1-score   support
#
#            0       0.74      0.97      0.84      4719
#            1       0.63      0.12      0.20      1833
#
#     accuracy                           0.73      6552
#    macro avg       0.69      0.55      0.52      6552
# weighted avg       0.71      0.73      0.66      6552
#
# Column: floods:
#
#                precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      6009
#            1       0.17      0.00      0.00       543
#
#     accuracy                           0.92      6552
#    macro avg       0.54      0.50      0.48      6552
# weighted avg       0.86      0.92      0.88      6552
#
# Column: storm:
#
#                precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95      5917
#            1       0.44      0.02      0.04       635
#
#     accuracy                           0.90      6552
#    macro avg       0.67      0.51      0.49      6552
# weighted avg       0.86      0.90      0.86      6552
#
# Column: fire:
#
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      6474
#            1       0.00      0.00      0.00        78
#
#     accuracy                           0.99      6552
#    macro avg       0.49      0.50      0.50      6552
# weighted avg       0.98      0.99      0.98      6552
#
# Column: earthquake:
#
#                precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96      5969
#            1       0.74      0.15      0.24       583
#
#     accuracy                           0.92      6552
#    macro avg       0.83      0.57      0.60      6552
# weighted avg       0.91      0.92      0.89      6552
#
# Column: cold:
#
#                precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      6408
#            1       0.00      0.00      0.00       144
#
#     accuracy                           0.98      6552
#    macro avg       0.49      0.50      0.49      6552
# weighted avg       0.96      0.98      0.97      6552
#
# Column: other_weather:
#
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      6208
#            1       0.20      0.00      0.01       344
#
#     accuracy                           0.95      6552
#    macro avg       0.57      0.50      0.49      6552
# weighted avg       0.91      0.95      0.92      6552
#
# Column: direct_report:
#
#                precision    recall  f1-score   support
#
#            0       0.81      0.99      0.89      5289
#            1       0.20      0.01      0.02      1263
#
#     accuracy                           0.80      6552
#    macro avg       0.51      0.50      0.46      6552
# weighted avg       0.69      0.80      0.72      6552

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
sorted(pipeline.get_params().keys())
# Out:
# ['clf',
#  'clf__estimator',
#  'clf__estimator__bootstrap',
#  'clf__estimator__ccp_alpha',
#  'clf__estimator__class_weight',
#  'clf__estimator__criterion',
#  'clf__estimator__max_depth',
#  'clf__estimator__max_features',
#  'clf__estimator__max_leaf_nodes',
#  'clf__estimator__max_samples',
#  'clf__estimator__min_impurity_decrease',
#  'clf__estimator__min_impurity_split',
#  'clf__estimator__min_samples_leaf',
#  'clf__estimator__min_samples_split',
#  'clf__estimator__min_weight_fraction_leaf',
#  'clf__estimator__n_estimators',
#  'clf__estimator__n_jobs',
#  'clf__estimator__oob_score',
#  'clf__estimator__random_state',
#  'clf__estimator__verbose',
#  'clf__estimator__warm_start',
#  'clf__n_jobs',
#  'memory',
#  'steps',
#  'tfidf',
#  'tfidf__norm',
#  'tfidf__smooth_idf',
#  'tfidf__sublinear_tf',
#  'tfidf__use_idf',
#  'vect',
#  'vect__analyzer',
#  'vect__binary',
#  'vect__decode_error',
#  'vect__dtype',
#  'vect__encoding',
#  'vect__input',
#  'vect__lowercase',
#  'vect__max_df',
#  'vect__max_features',
#  'vect__min_df',
#  'vect__ngram_range',
#  'vect__preprocessor',
#  'vect__stop_words',
#  'vect__strip_accents',
#  'vect__token_pattern',
#  'vect__tokenizer',
#  'vect__vocabulary',
#  'verbose']

# %%
#ref.: https://towardsdatascience.com/hyperparameter-tuning-the-random-forest-in-python-using-scikit-learn-28d2aa77dd74
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 5)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 3)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
parameters = {
        'vect__ngram_range': ((1, 1), (1, 2)),
        'vect__max_df': (0.5, 0.75, 1.0),
        'vect__max_features': (None, 5000, 10000),
        'tfidf__use_idf': (True, False),
        'clf__estimator__n_estimators': n_estimators,
        'clf__estimator__max_features': max_features,
        'clf__estimator__max_depth': max_depth,
        'clf__estimator__min_samples_split': min_samples_split,
        'clf__estimator__min_samples_leaf':min_samples_leaf,
        'clf__estimator__bootstrap': bootstrap
    }

cv = GridSearchCV(pipeline, param_grid=parameters,n_jobs=-1)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
cv.fit(X_train,y_train)

# %%
performance_report(cv,X_test,y_test)

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
